# %%
# !pip install tabula-py
# Out:
# ...
#   Found existing installation: pandas 0.25.1
#     Uninstalling pandas-0.25.1:
#       Successfully uninstalled pandas-0.25.1
# ...

# %%
import tabula
 
file = "http://www.mt.gov.br/documents/21013/13951649/Nota+Informativa+Coronav%C3%ADrus+de+27.03.20/90d61aff-c9bf-51f1-69bc-f3ff4197f021"
 
tables = tabula.read_pdf(file, pages = "all", multiple_tables = True, encoding='utf-8')
# Out:
# Got stderr: mar 31, 2020 10:53:11 AM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Cambria are not implemented in PDFBox and will be ignored
# mar 31, 2020 10:53:12 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES: Your current java version is: 1.8.0_171
# mar 31, 2020 10:53:12 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES: To get higher rendering speed on old java 1.8 or 9 versions,
# mar 31, 2020 10:53:12 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# mar 31, 2020 10:53:12 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   or
# mar 31, 2020 10:53:12 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# ...

# %%
tables[4:7]
# Out:
# [   07 Nova Monte Verde  F  32  19/03
#  0   8    Várzea Grande  F  26  20/03
#  1   9           Cuiabá  M  36  20/03
#  2  10           Cuiabá  M  47  24/03
#  3  11           Cuiabá  F  37  24/03,
#      Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
#  0          NaN  Secretaria Adjunta de Atenção e Vigilância em ...         NaN
#  1          NaN                                                  5         1.0
#  2          NaN                                                  5         1.0
#  3          NaN                                                NaN        16.0
#  4          NaN                                                 32         NaN
#  5          NaN                                                  1         NaN
#  6          NaN                                                NaN         1.0
#  7          NaN                                                NaN         3.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0fcad06fa51f> in <module>
# ----> 1 tabula.convert_into_by_batch("/path/to/files", output_format = "csv", pages = "all")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tabula\io.py in convert_into_by_batch(input_dir, output_format, java_options, **kwargs)
#     595
#     596     if input_dir is None or not os.path.isdir(input_dir):
# --> 597         raise ValueError("'input_dir' should be an existing directory path")
#     598
#     599     kwargs["format"] = _extract_format_for_conversion(output_format)
#
# ValueError: 'input_dir' should be an existing directory path

# %% [markdown]
# # Fonte de informaçoes
# * http://www.saude.mt.gov.br/arquivo/10805
# * http://theautomatic.net/2019/05/24/3-ways-to-scrape-tables-from-pdfs-with-python/
# * https://pypi.org/project/tabula-py/
# * https://tabula-py.readthedocs.io/en/latest/tabula.html
